# %%
import os
import logging
import pandas as pd
import numpy as np
import scipy.sparse as sp
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import normalize, OneHotEncoder, PolynomialFeatures
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_selection import chi2, mutual_info_classif, VarianceThreshold, SelectKBest
from sklearn.metrics.pairwise import linear_kernel, cosine_distances
from sklearn.cluster import KMeans, SpectralClustering, AgglomerativeClustering
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.pipeline import make_pipeline
from util import clean_data

logging.getLogger().setLevel(logging.INFO)
np.random.seed(1234567)

# %%
def load_data(prefix, ids, suffix='mb01dz.csv'):
    '''加载方言字音数据'''

    logging.info('loading {} data files ...'.format(len(ids)))

    load_ids = []
    dialects = []
    for id in ids:
        try:
            fname = os.path.join(prefix, id + suffix)
            logging.info(f'loading {fname} ...')
            d = pd.read_csv(
                fname,
                encoding='utf-8',
                index_col='iid',
                usecols=('iid', 'initial', 'finals', 'tone'),
                dtype={ 'iid': int, 'initial': str, 'finals': str, 'tone': str}
            )
        except Exception as e:
            logging.error('cannot load file {}: {}'.format(fname, e))
            continue

        d = clean_data(d)
        dialects.append(d)
        load_ids.append(id)

    logging.info('done. {} data loaded'.format(len(dialects)))

    data = pd.concat(
        [d.groupby(d.index).agg(' '.join) for d in dialects],
        axis=1,
        keys=load_ids
    ).dropna(axis=0, how='all').fillna('')

    logging.info(f'load data of {data.shape[0]} characters x {len(dialects)} dialects, ' \
        + f'{sum(d.shape[0] for d in dialects)} valid records')
    return data

def encode_data(data):
    features = []
    limits = []
    for col in data.columns.levels[1]:
        d = data.loc[:, (slice(None), col)]

        fea = []
        cat = []
        for i in range(d.shape[1]):
            cv = CountVectorizer(lowercase=False, token_pattern=r'\S+', binary=True)
            fea.append(cv.fit_transform(d.iloc[:, i]))
            cat.append(len(cv.vocabulary_))

        features.append(sp.hstack(fea, format='csr'))
        limits.append(np.insert(np.cumsum(cat), 0, 0))

    return features, limits

def get_cluster(features, p=0.99, cluster=200):
    vt = VarianceThreshold(p * (1 - p))
    kmeans = KMeans(cluster).fit(vt.fit_transform(features))
    logging.info(f'keep {vt.get_support(indices=True).shape[0]}/{features.shape[1]} after filtered')
    return vt.get_support(indices=True), kmeans.labels_, sp.csr_matrix(kmeans.cluster_centers_)

def get_homophone(features, limits):
    indices = np.triu_indices(features.shape[0])
    homophone = sp.vstack(
        [sp.csr_matrix(linear_kernel(features[:, limits[i]:limits[i + 1]])[indices]) \
            for i in range(limits.shape[0] - 1)],
        format='csr'
    )
    return homophone, indices

def merge_homophone(homophome, p=0.998, clusters=1000):
    vt = VarianceThreshold(p * (1 - p))
    kmeans = KMeans(clusters).fit(vt.fit_transform(homophome).T)
    logging.info(f'keep {vt.get_support(indices=True).shape[0]}/{homophone.shape[1]} after filtered')
    return vt.get_support(indices=True), kmeans.labels_, kmeans.cluster_centers_.T

# %%
def clean_dialect_tag(tag):
    return np.where(
        tag.str.contains('[吴闽赣粤湘晋徽]'),
        tag.str.replace('.*([吴闽赣粤湘晋徽]).*', r'\1方言', regex=True),
        np.where(
            tag.str.contains('客'),
            tag.str.replace('.*(客).*', '客家方言', regex=True),
            np.where(
                tag.str.contains('平话'),
                tag.str.replace('.*平话.*', '平话', regex=True),
                np.where(
                    tag.str.contains('北京|东北|冀鲁|胶辽|中原|兰银|江淮|西南'),
                    tag.str.replace('.*(北京|东北|冀鲁|胶辽|中原|兰银|江淮|西南).*', r'\1官话', regex=True),
                    np.where(
                        tag.str.contains('湖南|韶州'),
                        tag.str.replace('.*(湖南|韶州).*', '\1土话', regex=True),
                        np.nan
                    )
                )
            )
        )
    )

def get_dialect(location):
    dialect = pd.Series(clean_dialect_tag(location['area']), index=location.index)
    return dialect.where(dialect.notna(), clean_dialect_tag(location['slice']))

# %%
prefix = r'D:\git\zhongguoyuyan\csv'
location = pd.read_csv(os.path.join(prefix, 'dialect', 'location.csv'), index_col=0)
char = pd.read_csv(os.path.join(prefix, 'words.csv'), index_col=0)

# %%
data = load_data(os.path.join(prefix, 'dialect'), location.sample(100).index)
data = data[data.index.isin(char.index)]
codes, limits = encode_data(data)

clusters = []
cluster_names = []
homophones = []
rule_names = []
rule_group_names = []
for code, lim in zip(codes, limits):
    _, cl, centers = get_cluster(code)
    cl_name = char.groupby(cl)['item'].agg(''.join).reindex(np.arange(centers.shape[0]))
    features = sp.vstack([sp.csr_matrix(code[cl == i].mean(axis=0)) for i in range(centers.shape[0])])
    homophone, indices = get_homophone(features, lim)
    rule_name = pd.Series(f'{cl_name.loc[indices[0][j]]}={cl_name.loc[indices[1][j]]}' for j in range(indices[0].shape[0]))
    idx, homophone_cluster, homophone_centers = merge_homophone(homophone)
    homophone_cluster = pd.Series(homophone_cluster, index=idx)
    rule_group_name = rule_name[idx].groupby(homophone_cluster).agg(' '.join).reindex(np.arange(homophone_centers.shape[0]))
    clusters.append(cl)
    cluster_names.append(cl_name)
    homophones.append(homophone)
    rule_names.append(rule_name)
    rule_group_names.append(rule_group_name)
# Out:
# INFO:root:loading 100 data files ...
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\03E89mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 91
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\10114mb01dz.csv ...
# WARNING:root:replace ￻ -> _ 129
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\14E63mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 57
# WARNING:root:replace ʨh -> tɕh 1
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\15972mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 93
# WARNING:root:replace 学～ ->  1
# WARNING:root:replace ～然 ->  1
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\28396mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 115
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\26A39mb01dz.csv ...
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\10G71mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 135
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\21352mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 112
# WARNING:root:replace 文 ->  1
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\01021mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 143
# WARNING:root:replace ʧ -> tʃ 106
# WARNING:root:replace ʧh -> tʃh 91
# WARNING:root:replace ʦ -> ts 4
# WARNING:root:replace ʦh -> tsh 2
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\12D80mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 119
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\26A38mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 114
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\01E08mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 79
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\27388mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 78
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\04G92mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 37
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\26D44mb01dz.csv ...
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\11580mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 118
# WARNING:root:replace ø -> ∅ 1
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\10G62mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 129
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\26J62mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 111
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\02194mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 115
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\08F59mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 147
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\10093mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 123
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\16C15mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 109
# WARNING:root:replace ʨ -> tɕ 3
# WARNING:root:replace ʨh -> tɕh 2
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\10075mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 129
# WARNING:root:replace ʨ -> tɕ 76
# WARNING:root:replace ʦ -> ts 75
# WARNING:root:replace ʦh -> tsh 61
# WARNING:root:replace ʨh -> tɕh 44
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\26511mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 126
# WARNING:root:replace ʦh -> tsh 1
# WARNING:root:replace ʨ -> tɕ 1
# WARNING:root:replace ʨh -> tɕh 1
# WARNING:root:replace 3+J6024 -> 324 1
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\09D90mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 97
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\06F94mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 141
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\05294mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 84
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\12D86mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 105
# WARNING:root:replace 文。～心 ->  1
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\01E17mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 108
# WARNING:root:replace ʧ -> tʃ 57
# WARNING:root:replace ʧh -> tʃh 50
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\25590mb01dz.csv ...
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\02190mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 115
# WARNING:root:replace ʦh -> tsh 4
# WARNING:root:replace ʦ -> ts 1
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\26D51mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 109
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\16C36mb01dz.csv ...
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\09A78mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 116
# WARNING:root:replace ʦ -> ts 94
# WARNING:root:replace ʦh -> tsh 71
# WARNING:root:replace ʨ -> tɕ 63
# WARNING:root:replace ʨh -> tɕh 31
# WARNING:root:replace ᴀ o -> ᴀo 34
# WARNING:root:replace iᴀ o -> iᴀo 22
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\16C01mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 110
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\16C10mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 113
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\02G41mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 103
# WARNING:root:replace ʦh -> tsh 1
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\15F48mb01dz.csv ...
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\18930mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 91
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\01028mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 115
# WARNING:root:replace ʧ -> tʃ 41
# WARNING:root:replace ʧh -> tʃh 34
# WARNING:root:replace tʃʰ -> tʃh 8
# WARNING:root:replace tʰ -> th 5
# WARNING:root:replace ʧʰ -> tʃh 2
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\07245mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 127
# WARNING:root:replace ʦh -> tsh 1
# WARNING:root:replace ʨ -> tɕ 1
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\15F50mb01dz.csv ...
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\10G65mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 44
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\10G81mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 126
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\07J32mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 139
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\16F11mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 105
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\13C46mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 112
# WARNING:root:replace 文 ->  2
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\08964mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 144
# WARNING:root:replace g -> ɡ 6
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\07247mb01dz.csv ...
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\08K30mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 138
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\24J27mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 85
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\15F49mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 139
# WARNING:root:replace ʦh -> tsh 12
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\07D30mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 100
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\01E10mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 116
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\35H16mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 141
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\10G77mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 144
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\16C11mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 111
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\26J44mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 115
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\01J73mb01dz.csv ...
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\16302mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 112
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\06F96mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 119
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\11289mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 125
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\28394mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 99
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\26502mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 97
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\08522mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 134
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\26D58mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 126
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\13331mb01dz.csv ...
# WARNING:root:replace ʨh -> tɕh 1
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\26J49mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 123
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\15J12mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 71
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\02196mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 89
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\08528mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 162
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\01G26mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 111
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\11576mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 119
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\13189mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 106
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\13C41mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 110
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\22598mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 136
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\16F20mb01dz.csv ...
# WARNING:root:replace ʨ -> tɕ 1
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\15F53mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 110
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\01E04mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 106
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\18J82mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 112
# WARNING:root:replace ʨ -> tɕ 50
# WARNING:root:replace ʨh -> tɕh 47
# WARNING:root:replace ʦ -> ts 14
# WARNING:root:replace ʦh -> tsh 4
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\27F82mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 91
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\24G02mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 115
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\02A15mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 111
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\06572mb01dz.csv ...
# WARNING:root:replace 新 ->  1
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\15236mb01dz.csv ...
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\26516mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 119
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\08969mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 160
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\07D37mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 113
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\08K19mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 138
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\18E43mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 54
# WARNING:root:replace ￻ -> _ 40
# WARNING:root:replace ʦ -> ts 1
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\16F15mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 106
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\02G50mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 123
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\24G12mb01dz.csv ...
# WARNING:root:replace ～赢 ->  1
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\02552mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 114
# WARNING:root:replace ʦ -> ts 1
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\20313mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 94
# WARNING:root:replace s
# s -> ss 1
# WARNING:root:replace æ
# ə -> æə 1
# WARNING:root:replace 53
# 53 -> 5353 1
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\25D18mb01dz.csv ...
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\18372mb01dz.csv ...
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\18E46mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 104
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\02539mb01dz.csv ...
# WARNING:root:replace Ǿ -> ∅ 111
# INFO:root:loading D:\git\zhongguoyuyan\csv\dialect\21A34mb01dz.csv ...
# INFO:root:done. 100 data loaded
# INFO:root:load data of 1000 characters x 100 dialects, 104419 valid records
# INFO:root:keep 3032/4324 after filtered
# INFO:root:keep 7639/20100 after filtered
# INFO:root:keep 2053/2169 after filtered
# INFO:root:keep 8687/20100 after filtered
# INFO:root:keep 548/560 after filtered
# INFO:root:keep 19968/20100 after filtered

# %%
display(cluster_names)
display(rule_group_names)
# Out:
# [0                 箍古苦裤吴五虎壶户乌
#  1                          缚
#  2                         绝雪
#  3                        厌炎盐
#  4      柄平病明命镜影饼名领井清姓轻赢钉厅听零青星
#                 ...
#  195                        吞
#  196                   力壁劈踢笛历
#  197                        让
#  198                       甲鸭
#  199             胎台袋来菜财该改海爱盖害
#  Name: item, Length: 200, dtype: object,
#  0                    芋意衣腰要优幼厌音烟印一隐秧样约蝇影益育拥
#  1                                    猪主转砖准
#  2                       锁岁死四丝嫂三伞酸算孙笋索塞送松宋缩
#  3                                        嫩
#  4      把布贝拜摆杯碑比宝包饱表扮八班板变扁憋搬半拨笔本帮绑剥北冰逼百兵柄饼壁
#                        ...
#  195                                      剩
#  196                                  西洗息惜锡
#  197                                    去器气
#  198                                      择
#  199                             吕犁梨李料立连律亮力
#  Name: item, Length: 200, dtype: object,
#  0                                                      迎
#  1      嫁借化布做锯付爱带盖拜晒对碎怪挂岁肺戏四试记醉费贵罩孝笑照要钓叫够瘦暗占剑变线扇见半算印劲粪...
#  2                     拖初区胎开梯吹亏抄敲偷贪签添天牵圈吞亲村春汤仓糠疮筐窗坑清轻青葱充冲
#  3      左可躲锁果把假哑姐写谱赌土古苦所鼠许府取主改海摆解拐纸比死子喜几水鬼早草好饱找鸟抖狗口酒手九...
#  4                                               吉橘得福竹菊足烛
#                               ...
#  195                                                    撤
#  196                                                    特
#  197                                                    寺
#  198                                                    妹
#  199                                                    削
#  Name: item, Length: 200, dtype: object]
# [0                     菊育曲局玉浴=靴月越决缺 菊育曲局玉浴=血 靴月越决缺=肉 肉=血
#  1                                    冷省耕=冷省耕 冷省耕=生更梗坑硬争
#  2                    阔活=着弱 果过火货祸=着弱 多拖锣左躲螺坐锁错所=着弱 脱夺=着弱
#  3     冻痛动洞弄粽送宋=朋猛棚 东懂通桶铜聋葱冬脓松=朋猛棚 宫龙松恭共=朋猛棚 朋猛棚=中虫终充...
#  4                 竹畜粥叔熟烛属=赌土图杜奴路租初锄数数 赌土图杜奴路租初锄数数=读鹿族毒赎
#                              ...
#  95                                  集急及吸匹七吉一=日 鼻立习笔密栗=日
#  96    百拍白麦=贝杯配赔背煤妹碑 百拍白麦=肺飞费肥 得特刻黑测=贝杯配赔背煤妹碑 得特刻黑测=肺...
#  97    冻痛动洞弄粽送宋=横 东懂通桶铜聋葱冬脓松=横 宫龙松恭共=横 横=中虫终充重肿种冲 横=公...
#  98                            搭踏杂塔蜡插闸=杉 法达辣擦八扎杀发罚=杉 杉=大
#  99    西洗鸡溪契系=吹水 西洗鸡溪契系=灰回会 西洗鸡溪契系=垂追锤 抖偷头豆楼走瘦=朝照烧 桂规...
#  Length: 100, dtype: object,
#  0                                           竖树顺=鼠 书输水=鼠
#  1     下夏校限学行=寺随 程=区圈劝缺曲 左租做紫资子嘴醉早灶走卒作粽足=柿 终肿种烛=柿 州折针...
#  2                                         窄=窄 窄=纸指罩找扎争摘
#  3     间角=茄渠棋桥球权裙穷 可开口看渴糠壳肯坑客哭=区圈劝缺曲 可开口看渴糠壳肯坑客哭=溪 茄渠...
#  4                                               猪主转砖准=柱
#                              ...
#  95                                                  师=僧
#  96                                             撞=锤虫 撞=垂
#  97    爱矮暗安恩=现县形 爱矮暗安恩=滑还横 哑鸭=现县形 哑鸭=滑还横 现县形=吴五乌握屋 现县...
#  98    华回会怀坏画魂划=货霍 华回会怀坏画魂划=海好喊汉鹤黑烘 号厚含汗=火花化灰欢婚慌 货霍=话...
#  99    芋意衣腰要优幼厌音烟印一隐秧样约蝇影益育拥=铅 歪卫位围胃完碗挖弯温王旺翁=铅 铅=圆院冤园...
#  Length: 100, dtype: object,
#  0     左可躲锁果把假哑姐写谱赌土古苦所鼠许府取主改海摆解拐纸比死子喜几水鬼早草好饱找鸟抖狗口酒手九...
#  1     左可躲锁果把假哑姐写谱赌土古苦所鼠许府取主改海摆解拐纸比死子喜几水鬼早草好饱找鸟抖狗口酒手九...
#  2     递=作各策 递=侧测 谢射父币卫义类胃校验任恨旺凤共=作各策 谢射父币卫义类胃校验任恨旺凤共...
#  3     迎=拥 嫁借化布做锯付爱带盖拜晒对碎怪挂岁肺戏四试记醉费贵罩孝笑照要钓叫够瘦暗占剑变线扇见半...
#  4     日=贼 物=贼 叶篾月麦六=贼 业立入灭列末越弱历鹿=贼 栗=贼 孽木目=贼 属=贼 落=贼...
#                              ...
#  95    嫁借化布做锯付爱带盖拜晒对碎怪挂岁肺戏四试记醉费贵罩孝笑照要钓叫够瘦暗占剑变线扇见半算印劲粪...
#  96    吉橘得福竹菊足烛=个 铁尺=个 剥拍=个 桌=个 锡=个 笔骨北谷=个 搭插擦扎托拆摘=个 ...
#  97    铁尺=恶 剥拍=恶 桌=恶 搭插擦扎托拆摘=恶 接贴瞎歇切泼脱缺踢吃=恶 折壳国格隔=恶 恶...
#  98                                                  肉=项
#  99    左可躲锁果把假哑姐写谱赌土古苦所鼠许府取主改海摆解拐纸比死子喜几水鬼早草好饱找鸟抖狗口酒手九...
#  Length: 100, dtype: object]

# %%
clusters = pd.DataFrame(np.column_stack(clusters), index=data.index, columns=data.columns.levels[1])
tmp = pd.concat([char[['item']].reindex(clusters.index).fillna(''), clusters], axis=1, join='inner')
cluster_names = [tmp.groupby(c)['item'].agg(''.join) for c in clusters.columns]

for name in cluster_names:
    display(name)
# Out:
# finals
# 0            紫刺资死四子字丝祠寺
# 1                皮比屁地梨李
# 2                  吞墩蹲轮
# 3                    猪鼠
# 4      品贫民邻进亲新紧银印引筋劲勤近隐
#              ...
# 195                   骨
# 196                   兄
# 197                 木服目
# 198                   硬
# 199                 网王旺
# Name: item, Length: 199, dtype: object
# initial
# 0             意衣腰要优幼厌音烟印一隐秧约蝇影益拥
# 1                           举句卷橘
# 2                            碎岁笋
# 3      锣螺路来雷类老楼拉蓝蜡兰懒烂辣乱轮浪落冷聋鹿六龙绿
# 4           大杜袋弟递地道豆淡碟达垫断夺定笛动洞读毒
#                  ...
# 195                           任褥
# 196                         桃头潭糖
# 197                          决均军
# 198                            弄
# 199                            辰
# Name: item, Length: 199, dtype: object
# tone
# 0                                                 吉橘竹菊足烛
# 1                                                      费
# 2      多歌靴沙瓜花租乌猪书输该街低西鸡溪杯灰歪碑知资饥丝衣规追龟飞刀高包抓交焦烧腰箫钩修州休优丢三...
# 3                                     可谱所府解拐紫感险品产典显反隐党纺孔
# 4                                                     林连
#                              ...
# 195                                                    胖
# 196                                                    兴
# 197                                                    市
# 198    躲锁果火假哑姐写赌古苦虎许主改海摆矮洗纸比死子喜几嘴水鬼宝早嫂好饱找小抖走狗酒手九胆敢减点板...
# 199                                                    屋
# Name: item, Length: 199, dtype: object

# %%
features = np.column_stack(homophone_centers)
labels = get_dialect(location)
train_location, test_location, train_features, test_features, train_target, test_target = train_test_split(
    location[labels.notna()],
    features[labels.notna()],
    labels[labels.notna()],
    test_size=0.2
)

# %%
selector = SelectKBest(chi2, k=10000)
features = selector.fit_transform(train_features, train_target)

# %%
feature_names = pd.Series([f'{clusters.columns[i]}:{cluster_names[i].loc[indices[i][0][j]]}={cluster_names[i].loc[indices[i][1][j]]}' for i in range(len(cluster_names)) for j in range(indices[i][0].shape[0])])
display(feature_names[np.argsort(-selector.scores_)[:100]])
# Out:
# 13367                                        finals:项=荣永
# 21279    initial:把布贝拜摆杯碑比宝包饱表扮八班板变扁憋搬半拨笔本帮绑剥北冰逼百兵柄饼壁=肥饭房
# 27860                                   initial:下学=欠牵劝庆轻
# 10916                                       finals:正声城=兄
# 33203                                   initial:鞋咸=欠牵劝庆轻
#                               ...
# 35244                                initial:课苦裤块快宽阔=肥饭房
# 37258                            initial:乌歪卫位围胃碗挖弯温握翁屋=项
# 42574                                   tone:笔骨北得色谷福宿曲=伞
# 26605                                 initial:火货花化灰欢婚慌=鱼
# 23834        initial:多躲赌带低对刀钓抖丢搭胆点店跌单典端短墩蹲党灯等凳得打钉顶东懂冻冬=传
# Length: 100, dtype: object

# %%
kmeans = KMeans(1000).fit(features.T)
feature_group_names = feature_names[selector.get_support()].groupby(kmeans.labels_).agg(' '.join)
display(feature_group_names)
# Out:
# 0      tone:校任恨凤=客 tone:坏画话换县认让=客 tone:柿=客 tone:淡=客 t...
# 1      finals:接叶业贴碟协孽捏=夹 finals:瓜瓦花化华挂画话划=外 finals:月越...
# 2      tone:鸽接贴歇切泼脱缺约剥=着 tone:笔骨北得色谷福宿曲=着 tone:刻侧测畜=着...
# 3      tone:林连=六 tone:河斜壶回骑朝含咸传船贫辰朋程瓶停横红=六 tone:茄婆爬茶蛇...
# 4               initial:下学=吸 initial:吸=虾瞎 initial:吸=夏校限行
#                              ...
# 995    finals:择=歌个可鹅饿河课 finals:歌个可鹅饿河课=虱特刻侧测色 finals:...
# 996                               finals:胎台袋来菜财该改开海爱盖害=还
# 997              initial:绕=艺蚁义 initial:绕=银 initial:绕=验严业
# 998                       initial:女泥黏念孽年捏娘=弱 initial:弱=牛
# 999    initial:写西洗小笑箫修心鲜线先选雪新想削息姓惜星锡=虾瞎 initial:下学=像 ...
# Length: 1000, dtype: object

# %%
def benchmark(features, target, estimators):
    for e in estimators:
        scores = cross_val_score(e, features, target)
        display(f'{e} {scores.mean()}+-{scores.std()}')

# %%
benchmark(train_features, train_target, (
    make_pipeline(
        # PolynomialFeatures(interaction_only=True, include_bias=False),
        LogisticRegression(penalty='l1', solver='saga')
    ),
    make_pipeline(
        # PolynomialFeatures(interaction_only=True, include_bias=False),
        SVC(),
    ),
    DecisionTreeClassifier(max_depth=20),
    GradientBoostingClassifier(n_estimators=20)
))
# Out:
# C:\Users\yihuahuang\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# C:\Users\yihuahuang\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\yihuahuang\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\yihuahuang\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\yihuahuang\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\yihuahuang\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# "Pipeline(steps=[('logisticregression',\n                 LogisticRegression(penalty='l1', solver='saga'))]) 0.8817950581395347+-0.013413653851443866"
# C:\Users\yihuahuang\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# "Pipeline(steps=[('svc', SVC())]) 0.8538032945736435+-0.014323550441179056"
# C:\Users\yihuahuang\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# 'DecisionTreeClassifier(max_depth=20) 0.7387839147286821+-0.041584076108233364'
# C:\Users\yihuahuang\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# 'GradientBoostingClassifier(n_estimators=20) 0.8087330426356589+-0.01007184009058067'

# %%
test_location.assign(label=test_target, pred=pred)[pred != test_target]
# Out:
#         longitude   latitude  insertDate  uploader firstLevelid  sheetName  \
# 05D22  119.641667  41.350000         NaN       NaN        05D22        NaN
# 15990  113.208333  25.233333         NaN       NaN        15990        NaN
# 08F70  119.316667  29.483333         NaN       NaN        08F70        NaN
# 35H24  109.700000  36.666667         NaN       NaN        35H24        NaN
# 11D10  115.391667  39.616667         NaN       NaN        11D10        NaN
# 26D48  111.253887  25.199988         NaN       NaN        26D48        NaN
# 23J18  108.658567  19.101105         NaN       NaN        23J18        NaN
# 02A10  117.100000  26.391667         NaN       NaN        02A10        NaN
# 14A65  102.866667  36.333333         NaN       NaN        14A65        NaN
# 35H13  109.941667  18.575000         NaN       NaN        35H13        NaN
# 06F93  118.525000  36.341667         NaN       NaN        06F93        NaN
# 28E70  109.891667  32.741667         NaN       NaN        28E70        NaN
# 02A19  117.141667  23.966667         NaN       NaN        02A19        NaN
# 01J69  111.212524  26.213593         NaN       NaN        01J69        NaN
# 26A60  112.925000  26.425000         NaN       NaN        26A60        NaN
#
#                                 filepath province city  country  ...  \
# 05D22         辽宁/凌源需交文件电子版/模板表/其他/概况.xls       辽宁  朝阳市      凌源市  ...
# 15990         广东/皈塘需交文件电子版/模板表/其他/概况.xls       广东   韶关       乐昌  ...
# 08F70         浙江/寿昌需交文件电子版/模板表/其他/概况.xls       浙江  杭州市      建德市  ...
# 35H24  濒危方言/陕西延安老户话需交文件电子版/模板表/其他/概况.xls     濒危方言   延安      宝塔区  ...
# 11D10         河北/涞水需交文件电子版/模板表/其他/概况.xls       河北   保定       涞水  ...
# 26D48         湖南/江永需交文件电子版/模板表/其他/概况.xls       湖南   永州       江永  ...
# 23J18       海南/东方军话需交文件电子版/模板表/其他/概况.xls       海南  （无）      东方市  ...
# 02A10         福建/明溪需交文件电子版/模板表/其他/概况.xls       福建  三明市      明溪县  ...
# 14A65         甘肃/红古需交文件电子版/模板表/其他/概况.xls       甘肃  兰州市      红古区  ...
# 35H13  濒危方言/海南陵水疍家话需交文件电子版/模板表/其他/概况.xls     濒危方言  （无）  陵水黎族自治县  ...
# 06F93         山东/临朐需交文件电子版/模板表/其他/概况.xls       山东   潍坊       临朐  ...
# 28E70         陕西/白河需交文件电子版/模板表/其他/概况.xls       陕西   安康       白河  ...
# 02A19      福建/诏安客家话需交文件电子版/模板表/其他/概况.xls       福建   漳州       诏安  ...
# 01J69       广西/全州土话需交文件电子版/模板表/其他/概况.xls       广西   桂林       全州  ...
# 26A60         湖南/耒阳需交文件电子版/模板表/其他/概况.xls       湖南   衡阳       耒阳  ...
#
#                                             minorityInfo  \
# 05D22                                                （无）
# 15990                                                （无）
# 08F70                                                （无）
# 35H24                                      无呈区域分布的少数民族语言
# 11D10                                本县无少数民族语言，少数民族均说汉语。
# 26D48  有过山瑶，又称高山瑶话，属于瑶族勉方言。主要分布在松柏、千家峒、兰溪、源口四个瑶族乡的少数村...
# 23J18  少数民族语言主要是黎语，人口约8.5万人；其次是哥隆话（村话），哥隆人民族成分归为汉族，但是...
# 02A10                                                （无）
# 14A65                                                （无）
# 35H13                                                （无）
# 06F93                                                （无）
# 28E70                                                （无）
# 02A19                                                （无）
# 01J69  本县少数民族语言有瑶语，主要分布在东山瑶族乡、蕉江瑶族乡部分地带。年轻一代多是既能讲瑶语，又...
# 26A60                                                （无）
#
#                                              dialectInfo  \
# 05D22  凌源方言属北京官话朝峰片。凌源处于北京、辽宁、河北三省交界地带，因此兼具多个官话方言区的特点...
# 15990  皈塘村委下辖各村小组所有人均说皈塘话。另外，从原皈塘村分出单立的现京口村的全部人，金鸡、新岩...
# 08F70  1.寿昌话，分布于旧寿昌县。2.建德话，主要分布于原建德县境内，一般一个镇一种口音，例如梅城...
# 35H24  本区主要有两种方言：老户话和上头话，同属于晋语。老户话，是延安的原住民方言，上头话是来自榆林...
# 11D10  涞水方言大致分为城关话和山区话两种，山区话主要指三坡镇、九龙镇方言，城关话指平原地带各乡镇方...
# 26D48  江永县的汉语方言有很多种，主要分为三大类：一类是以上江圩、城关潇浦镇为代表的土话，一类是以松...
# 23J18  汉语方言主要有军话（属西南官话）、海南话（属闽语）、儋州话（属粤语），其中军话主要分布在八所...
# 02A10  明溪县有四镇五乡。明溪话通常指建县以来的政治文化经济中心雪峰镇话。此外，城关乡、瀚仙镇、沙溪...
# 14A65  红古区方言内部口音有窑街口音和红古口音。窑街口音主要分布在区内窑街镇，其语音系统与兰州话基本...
# 35H13  新村镇通行当地闵语（海南话）和疍家话两种方言，全镇1万3千人基本会说海南话，其中将近1万人同...
# 06F93                               县内方言均属胶辽官话，没有明显内部差异。
# 28E70  城关话，分布在县境北部汉江南岸的城关、麻虎、冷水及县境东部的构朳；茅坪话：分布在县境西部、南...
# 02A19  县区内使用两种方言：客家方言，分布在西部山区，使用人口约21万，为日常主要生活用语；闽南方言...
# 01J69  （1）全州话，分布在全州镇及城郊、大西江、龙水、才湾、绍水、咸水、石塘、朝南、西河、安和、蕉...
# 26A60  本县方言只有汉语赣方言，内部略有差异（赣方言耒资片），分东南西北四个乡，其中东乡话与城关话最...
#
#                                                operaInfo  source      degree  \
# 05D22  皮影戏、评戏、京剧、京韵大鼓、二人转在当地比较流行。其中凌源皮影戏于2006年被列入第一批国...   yubao      common
# 15990                有少数老年人会唱花鼓戏（使用湖南衡阳一带的话）和客家山歌（使用客家话）   yubao      common
# 08F70                                      越剧、婺剧，在当地皆盛行。   yubao      common
# 35H24  延安宝塔区当下流行的地方曲艺有说书、民歌、晋剧、眉户戏等，但都不是本地原有的。用老户话说唱的...   yubao  endangered
# 11D10                                                （无）   yubao      common
# 26D48                                                （无）   yubao      common
# 23J18  军话民歌用军话演唱，形式一般为男女对唱，也有独唱、合唱、小组唱等；内容一般为表达爱情，也有思...   yubao      common
# 02A10            明溪县夏阳乡有大腔戏，系从永安引进，一般只在夏阳演出。明溪县城较少地方戏演出。   yubao      common
# 14A65  红古地区流行的主要剧种有秦腔、眉户。一般在年节、庙会演出或伴随社会庆典活动时演出，多为折子戏...   yubao      common
# 35H13  疍家调，原来叫咸水歌，新加坡、澳门、香港等地粤语人群都会唱。本地疍家人50岁以上才会唱，年轻...   yubao  endangered
# 06F93                                                （无）   yubao      common
# 28E70  白河花鼓戏。花鼓戏是白河常见的一种地方戏种类，属于安康花鼓戏（又称花鼓子）的一类。白河县城、...   yubao      common
# 02A19  县内演出潮剧，唱词用潮州话，对白多用诏安闽南话。另有一种“歌册”，用诏安闽南话演唱，七字一句...   yubao      common
# 01J69                             主要有彩调、渔鼓，流行于湘桂铁路沿线的乡镇。   yubao      common
# 26A60                               只有当地方言的歌谣，无地方曲艺和地方戏。   yubao      common
#
#         area  slice  slices  label  pred
# 05D22   北京官话    朝峰片    系属不明   北京官话  东北官话
# 15990   平话土话    韶州片    皈塘小片   平话方言   湘方言
# 08F70  徽语严州片   系属不明    系属不明    徽方言   吴方言
# 35H24     晋语    志延片    系属不明    晋方言  中原官话
# 11D10   冀鲁官话    保唐片    定霸小片   冀鲁官话  北京官话
# 26D48   湖南土话     永州      江永    土话   湘方言
# 23J18     官话   西南官话    海南军话   西南官话  江淮官话
# 02A10   客家话区    闽西片  闽客赣过渡片   客家方言   闽方言
# 14A65   兰银官话    金城片    红古小片   兰银官话  中原官话
# 35H13   中原官话    信蚌片    系属不明   中原官话   粤方言
# 06F93  胶辽官话区    青莱片    青临小片   胶辽官话  冀鲁官话
# 28E70     官话   中原官话  小片系属不明   中原官话  西南官话
# 02A19    客家话    汀州片    系属不明   客家方言   闽方言
# 01J69     平话   桂北平话    全州土话   平话方言   湘方言
# 26A60    赣方言    耒资片    系属不明    赣方言   湘方言
#
# [15 rows x 31 columns]
